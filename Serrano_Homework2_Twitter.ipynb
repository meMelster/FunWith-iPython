# %% [markdown]
# # Homework 2 - Option 2... #
# ###  Well Kinda....Requirements Modified ###
# #### Melissa Serrano ###
# The code below gets the Twitter trends for 5 locations of interest today, by using the countries WOEID.  I used a modified version of pygmaps, available under Issue 5 at https://code.google.com/p/pygmaps/.  This modified version enables the use of labels for the maps pinpoints.  When the user hovers over the pinpoint I display the top 5 trending topics on Twitter for the area indicated by th pin point on the map.

# %%
import twitter
import json
import pygmaps
import webbrowser
import pprint


CONSUMER_KEY = 'qAhZWyyxyi8MQZwxaCKojiC8O'
CONSUMER_SECRET = 'vCvQvS8icQpNucs5e42JZ0YqdmZkFg6QeGE3PH1sSUeZYyKzvC'
OAUTH_TOKEN = '2892604311-sLujj8H3JB5oHbIVPGZhC2vkZYNbW3CJsh2LICs'
OAUTH_TOKEN_SECRET = '9MFpHT1HKFmMyf3XD1UzH8APE0QwpkgbDEqt95GHmWQcw'
auth = twitter.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET, CONSUMER_KEY, CONSUMER_SECRET)
twitter_api = twitter.Twitter(auth=auth)


#Create a google map with the origin in the center of the laid out world
#zoom is 2 so that we can see all countries
mymap = pygmaps.maps(0, 0, 3)

for i in range(1,6):
    if i == 1:
        #Israel
        name = 'Israel'
        trends = twitter_api.trends.place(_id=23424852)
        lat = 31.00
        lon = 35.00
    if i == 2:
        #Mexico
        name = 'Mexico'
        trends = twitter_api.trends.place(_id=23424900)
        lat = 19.428
        lon = -99.127
    if i == 3:
        #Brazil
        name = 'Brazil'
        trends = twitter_api.trends.place(_id=23424768)
        lat = -15.7797
        lon = -47.9297
    if i == 4:
        #France
        name = 'France'
        trends = twitter_api.trends.place(_id=23424819)
        lat = 48.8534
        lon = 2.3488
    if i == 5:
        #Russia
        name = 'Russia'
        trends = twitter_api.trends.place(_id=23424936)
        lat = 60.00
        lon = 90.00

    stop = len(trends[0]['trends'])
    print stop
    trendsLabel = [None]*5
    for i in range(0,stop):
        try:
            trendsLabel[i] = trends[0]['trends'][i]['name']
            print i
        except KeyError, e:
            print e
        finally:
            #print 'trendsLabel['+str(i)+'] = ' + str(trendsLabel[i])
            if i == 5:
                break
    pp.pprint(trendsLabel)
    mymap.addpoint(lat, lon, "#FF0000", str(trendsLabel))
    print json.dumps(trends, indent=1)
    print



#draw the google map with all our coordinates on it 
#and save it in this directory    
mymap.draw('./mymap.html')
#open this file in the browser automatically
webbrowser.open_new('mymap.html')
# Out:
# 10
# 0
# 1
# 2
# 3
# 4
# [u'Palestinians', u'Iran', u'Purim', u'Zionist', u'Jews']
# [
#  {
#   "created_at": "2015-03-08T22:39:34Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=Palestinians",
#     "query": "Palestinians",
#     "name": "Palestinians",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Iran",
#     "query": "Iran",
#     "name": "Iran",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Purim",
#     "query": "Purim",
#     "name": "Purim",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Zionist",
#     "query": "Zionist",
#     "name": "Zionist",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Jews",
#     "query": "Jews",
#     "name": "Jews",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D7%94%D7%A1%D7%95%D7%A3_%D7%A9%D7%9C%D7%90_%D7%90%D7%95%D7%9E%D7%A8%D7%99%D7%9D",
#     "query": "%23%D7%94%D7%A1%D7%95%D7%A3_%D7%A9%D7%9C%D7%90_%D7%90%D7%95%D7%9E%D7%A8%D7%99%D7%9D",
#     "name": "#\u05d4\u05e1\u05d5\u05e3_\u05e9\u05dc\u05d0_\u05d0\u05d5\u05de\u05e8\u05d9\u05dd",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22West+Bank%22",
#     "query": "%22West+Bank%22",
#     "name": "West Bank",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Syria",
#     "query": "Syria",
#     "name": "Syria",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Spurs",
#     "query": "Spurs",
#     "name": "Spurs",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Shabbat+Shalom%22",
#     "query": "%22Shabbat+Shalom%22",
#     "name": "Shabbat Shalom",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2015-03-08T22:43:25Z",
#   "locations": [
#    {
#     "woeid": 23424852,
#     "name": "Israel"
#    }
#   ]
#  }
# ]
#
# 10
# 0
# 1
# 2
# 3
# 4
# [   u'#FelizDiaDeLaMujer',
#     u'#InternationalWomensDay',
#     u'#APumasLeUrge',
#     u'#esdemujeres',
#     u'#LOTPVideoTuesday']
# [
#  {
#   "created_at": "2015-03-08T22:39:32Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23FelizDiaDeLaMujer",
#     "query": "%23FelizDiaDeLaMujer",
#     "name": "#FelizDiaDeLaMujer",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23InternationalWomensDay",
#     "query": "%23InternationalWomensDay",
#     "name": "#InternationalWomensDay",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23APumasLeUrge",
#     "query": "%23APumasLeUrge",
#     "name": "#APumasLeUrge",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23esdemujeres",
#     "query": "%23esdemujeres",
#     "name": "#esdemujeres",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LOTPVideoTuesday",
#     "query": "%23LOTPVideoTuesday",
#     "name": "#LOTPVideoTuesday",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Talan+800%22",
#     "query": "%22Talan+800%22",
#     "name": "Talan 800",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Feliz+D%C3%ADa%22",
#     "query": "%22Feliz+D%C3%ADa%22",
#     "name": "Feliz D\u00eda",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Mujeres",
#     "query": "Mujeres",
#     "name": "Mujeres",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Ra%C3%BAl+Jim%C3%A9nez%22",
#     "query": "%22Ra%C3%BAl+Jim%C3%A9nez%22",
#     "name": "Ra\u00fal Jim\u00e9nez",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Titanic",
#     "query": "Titanic",
#     "name": "Titanic",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2015-03-08T22:43:26Z",
#   "locations": [
#    {
#     "woeid": 23424900,
#     "name": "Mexico"
#    }
#   ]
#  }
# ]
#
# 10
# 0
# 1
# 2
# 3
# 4
# [   u'#OnTheRunNoMultishow',
#     u'#TamiresNossaCampea',
#     u'#VoltaAlineGotschalgBBB15',
#     u'#felizDiainternacionaldaMulher',
#     u'Boninho']
# [
#  {
#   "created_at": "2015-03-08T22:39:31Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23OnTheRunNoMultishow",
#     "query": "%23OnTheRunNoMultishow",
#     "name": "#OnTheRunNoMultishow",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TamiresNossaCampea",
#     "query": "%23TamiresNossaCampea",
#     "name": "#TamiresNossaCampea",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23VoltaAlineGotschalgBBB15",
#     "query": "%23VoltaAlineGotschalgBBB15",
#     "name": "#VoltaAlineGotschalgBBB15",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23felizDiainternacionaldaMulher",
#     "query": "%23felizDiainternacionaldaMulher",
#     "name": "#felizDiainternacionaldaMulher",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Boninho",
#     "query": "Boninho",
#     "name": "Boninho",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LOTPVideoTuesday",
#     "query": "%23LOTPVideoTuesday",
#     "name": "#LOTPVideoTuesday",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Naughty+Girl%22",
#     "query": "%22Naughty+Girl%22",
#     "name": "Naughty Girl",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Tadinha+da+Amanda%22",
#     "query": "%22Tadinha+da+Amanda%22",
#     "name": "Tadinha da Amanda",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Alcione",
#     "query": "Alcione",
#     "name": "Alcione",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Tenho+1%2C75%22",
#     "query": "%22Tenho+1%2C75%22",
#     "name": "Tenho 1,75",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2015-03-08T22:43:26Z",
#   "locations": [
#    {
#     "woeid": 23424768,
#     "name": "Brazil"
#    }
#   ]
#  }
# ]
#
# 10
# 0
# 1
# 2
# 3
# 4
# [   u'#MHSCOL',
#     u'#UnBonheurnarrivejamaisseul',
#     u'#RipEminem',
#     u'#LOTPVideoTuesday',
#     u'Fekir']
# [
#  {
#   "created_at": "2015-03-08T22:39:32Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23MHSCOL",
#     "query": "%23MHSCOL",
#     "name": "#MHSCOL",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23UnBonheurnarrivejamaisseul",
#     "query": "%23UnBonheurnarrivejamaisseul",
#     "name": "#UnBonheurnarrivejamaisseul",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23RipEminem",
#     "query": "%23RipEminem",
#     "name": "#RipEminem",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LOTPVideoTuesday",
#     "query": "%23LOTPVideoTuesday",
#     "name": "#LOTPVideoTuesday",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Fekir",
#     "query": "Fekir",
#     "name": "Fekir",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Lyon+5-1%22",
#     "query": "%22Lyon+5-1%22",
#     "name": "Lyon 5-1",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23OLMHSC",
#     "query": "%23OLMHSC",
#     "name": "#OLMHSC",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Yattara",
#     "query": "Yattara",
#     "name": "Yattara",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Paris+4-1%22",
#     "query": "%22Paris+4-1%22",
#     "name": "Paris 4-1",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Marseille+6-1%22",
#     "query": "%22Marseille+6-1%22",
#     "name": "Marseille 6-1",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2015-03-08T22:43:27Z",
#   "locations": [
#    {
#     "woeid": 23424819,
#     "name": "France"
#    }
#   ]
#  }
# ]
#
# 10
# 0
# 1
# 2
# 3
# 4
# [   u'#\u041e\u0422\u0422\u0420\u0410\u0425\u0410\u041d\u041d\u042b\u0419\u0421\u041b\u041e\u041d',
#     u'#HappyBirthdayShannonLeto',
#     u'#8\u043c\u0430\u0440\u0442\u0430',
#     u'#\u0421\u043f\u0430\u0440\u0442\u0430\u043a\u041a\u0440\u0430\u0441\u043d\u043e\u0434\u0430\u0440',
#     u'\u0412\u0441\u0435\u0445 \u0441 8']
# [
#  {
#   "created_at": "2015-03-08T22:39:35Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23%D0%9E%D0%A2%D0%A2%D0%A0%D0%90%D0%A5%D0%90%D0%9D%D0%9D%D0%AB%D0%99%D0%A1%D0%9B%D0%9E%D0%9D",
#     "query": "%23%D0%9E%D0%A2%D0%A2%D0%A0%D0%90%D0%A5%D0%90%D0%9D%D0%9D%D0%AB%D0%99%D0%A1%D0%9B%D0%9E%D0%9D",
#     "name": "#\u041e\u0422\u0422\u0420\u0410\u0425\u0410\u041d\u041d\u042b\u0419\u0421\u041b\u041e\u041d",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HappyBirthdayShannonLeto",
#     "query": "%23HappyBirthdayShannonLeto",
#     "name": "#HappyBirthdayShannonLeto",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%238%D0%BC%D0%B0%D1%80%D1%82%D0%B0",
#     "query": "%238%D0%BC%D0%B0%D1%80%D1%82%D0%B0",
#     "name": "#8\u043c\u0430\u0440\u0442\u0430",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D0%A1%D0%BF%D0%B0%D1%80%D1%82%D0%B0%D0%BA%D0%9A%D1%80%D0%B0%D1%81%D0%BD%D0%BE%D0%B4%D0%B0%D1%80",
#     "query": "%23%D0%A1%D0%BF%D0%B0%D1%80%D1%82%D0%B0%D0%BA%D0%9A%D1%80%D0%B0%D1%81%D0%BD%D0%BE%D0%B4%D0%B0%D1%80",
#     "name": "#\u0421\u043f\u0430\u0440\u0442\u0430\u043a\u041a\u0440\u0430\u0441\u043d\u043e\u0434\u0430\u0440",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22%D0%92%D1%81%D0%B5%D1%85+%D1%81+8%22",
#     "query": "%22%D0%92%D1%81%D0%B5%D1%85+%D1%81+8%22",
#     "name": "\u0412\u0441\u0435\u0445 \u0441 8",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22%D0%9E%D1%82%D0%BB%D0%B8%D1%87%D0%BD%D0%BE%D0%B5+8%22",
#     "query": "%22%D0%9E%D1%82%D0%BB%D0%B8%D1%87%D0%BD%D0%BE%D0%B5+8%22",
#     "name": "\u041e\u0442\u043b\u0438\u0447\u043d\u043e\u0435 8",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Russia",
#     "query": "Russia",
#     "name": "Russia",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LoveLustTour",
#     "query": "%23LoveLustTour",
#     "name": "#LoveLustTour",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%D0%A8%D0%B0%D1%80%D0%BB%D0%B8",
#     "query": "%D0%A8%D0%B0%D1%80%D0%BB%D0%B8",
#     "name": "\u0428\u0430\u0440\u043b\u0438",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%D0%A4%D1%80%D1%8D%D0%BD%D0%BA%D0%B0",
#     "query": "%D0%A4%D1%80%D1%8D%D0%BD%D0%BA%D0%B0",
#     "name": "\u0424\u0440\u044d\u043d\u043a\u0430",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2015-03-08T22:43:27Z",
#   "locations": [
#    {
#     "woeid": 23424936,
#     "name": "Russia"
#    }
#   ]
#  }
# ]
# True
